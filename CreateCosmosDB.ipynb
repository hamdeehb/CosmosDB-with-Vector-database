 0.01281383354216814, 0.01106099784374237, -0.002387483138591051, -0.01059760432690382, 0.021329525858163834, -0.013089182786643505, -0.0028105813544243574, 0.004116813186556101, 0.00487570371478796, -0.01493604015558958, -0.010664762929081917, 0.017125405371189117, 0.005402897950261831, 0.007985140196979046, 0.0020701594185084105, -0.030033260583877563, 0.010940112173557281, 0.009274582378566265, 0.016910498961806297, -0.01474799681454897, 0.03406276926398277, 0.05125533416867256, -0.003925411496311426, 0.005547288339585066, -0.005876364652067423, -0.0083813751116395, -0.029818354174494743, 0.028555775061249733, -0.06436466425657272, 0.012598926201462746, -0.04161137714982033, 0.003529176814481616, 0.026258956640958786, 0.013377964496612549, -0.02067137323319912, -0.018992410972714424, - ...

# %%
cosmos_url =  os.getenv("COSMOS_ENDPOINT")
cosmos_key =  os.getenv("COSMOS_KEY")
cosmos_database_name = "linkedin_data"
cosmos_container_name = "linkedin_data_vector"

cosmos_client = CosmosClient(cosmos_url, cosmos_key)

try:
    cosmos_database = cosmos_client.create_database_if_not_exists(
        id=cosmos_database_name
    )
except exceptions.CosmosResourceExistsError:
    cosmos_database = cosmos_client.get_database_client(cosmos_database_name)

indexing_policy = {
    "includedPaths": [{"path": "/*"}],
    "excludedPaths": [{"path": '/"_etag"/?', "path": "/request_vector/*"}],
    "vectorIndexes": [{"path": "/request_vector", "type": "diskANN"}],
}

vector_embedding_policy = {
    "vectorEmbeddings": [
        {
            "path": "/request_vector",
            "dataType": "float32",
            "distanceFunction": "cosine",
            "dimensions": 1536,  # This is the amount of dimensions for the text-embedding-ada-002 model
        }
    ]
}

try:
    cosmos_container = cosmos_database.create_container_if_not_exists(
        id=cosmos_container_name,
        partition_key=PartitionKey(path="/company"),
        indexing_policy=indexing_policy,
        vector_embedding_policy=vector_embedding_policy,
    )
    print(f"Container {cosmos_container_name} created")
except exceptions.CosmosHttpResponseError as e:
    print(f"Error creating container: {str(e)}")
# Out:
# 2025-05-29 13:29:16,485 - INFO - Request URL: 'https://linkedinsales.documents.azure.com:443/'
# Request method: 'GET'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Accept': 'application/json'
#     'Content-Length': '0'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# 2025-05-29 13:29:17,603 - INFO - Response status: 200
# Response headers:
#     'Content-Length': '1616'
#     'Date': 'Thu, 29 May 2025 05:29:17 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Microsoft-HTTPAPI/2.0'
#     'x-ms-gatewayversion': 'REDACTED'
#     'Cache-Control': 'no-store, no-cache'
#     'Pragma': 'no-cache'
#     'x-ms-max-media-storage-usage-mb': 'REDACTED'
#     'x-ms-media-storage-usage-mb': 'REDACTED'
#     'x-ms-databaseaccount-consumed-mb': 'REDACTED'
#     'x-ms-databaseaccount-reserved-mb': 'REDACTED'
#     'x-ms-databaseaccount-provisioned-mb': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Content-Location': 'REDACTED'
# 2025-05-29 13:29:17,611 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/'
# Request method: 'GET'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Accept': 'application/json'
#     'Content-Length': '0'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# 2025-05-29 13:29:18,770 - INFO - Response status: 200
# Response headers:
#     'Content-Length': '168'
#     'Date': 'Thu, 29 May 2025 05:29:18 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Microsoft-HTTPAPI/2.0'
#     'x-ms-gatewayversion': 'REDACTED'
#     'Cache-Control': 'no-store, no-cache'
#     'Pragma': 'no-cache'
#     'Strict-Transport-Security': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"00006117-0000-4d00-0000-683581830000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-item-lsn': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-item-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
#     'Content-Location': 'REDACTED'
# 2025-05-29 13:29:18,777 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/'
# Request method: 'GET'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Accept': 'application/json'
#     'Content-Length': '0'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# 2025-05-29 13:29:19,073 - INFO - Response status: 404
# Response headers:
#     'Content-Length': '6228'
#     'Date': 'Thu, 29 May 2025 05:29:18 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Microsoft-HTTPAPI/2.0'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Content-Location': 'REDACTED'
# 2025-05-29 13:29:19,085 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'Content-Length': '394'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:19,890 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '911'
#     'Date': 'Thu, 29 May 2025 05:29:19 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Microsoft-HTTPAPI/2.0'
#     'x-ms-gatewayversion': 'REDACTED'
#     'Cache-Control': 'no-store, no-cache'
#     'Pragma': 'no-cache'
#     'Strict-Transport-Security': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"0000e902-0000-4d00-0000-6837f0af0000"'
#     'x-ms-schemaversion': 'REDACTED'
#     'collection-partition-index': 'REDACTED'
#     'collection-service-index': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-item-lsn': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-cosmos-item-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-max-content-length': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# Container linkedin_data_vector created

# %%
def generate_openai_embeddings(input_text):
    client = AzureOpenAI(
    api_key = os.getenv("AZURE_OPENAI_API_KEY"),  
    api_version = "2025-01-01-preview",
    azure_endpoint =os.getenv("AZURE_OPENAI_ENDPOINT") 
    )

    response = client.embeddings.create(
        input = input_text,
        model= "text-embedding-ada-002"
    )

    return response.data[0].embedding

# %%
df = pd.read_csv("new_output.csv")
logger.info(f"Read {len(df)} records from CSV")
        
# Clean the data - fill NaN values
df = df.fillna("")

# Process and upload each record
successful_uploads = 0
failed_uploads = 0

for _, row in df.iterrows():
    try:
        # Create document structure
        document = {
            'id': str(uuid4()),  # Generate unique ID
            'full_name': row['full_name'],
            'full_name_url': row['full_name_url'],
            'role': row['role'],
            'company': row['company'] if row['company'] else "Unknown",  # Ensure partition key exists
            'time': int(row['time']) if row['time'] and pd.notna(row['time']) else 0,
            'activity': row['activity'],
            'interests': row['interests'],
            'experience_overview': row['experience_overview'],
            'experience_details': row['experience_details'],
            "request_vector": generate_openai_embeddings(row['company'])
        }
        
        # Upload document to CosmosDB
        cosmos_container.create_item(body=document)
        successful_uploads += 1
        
        # Log progress for every 10 records
        if successful_uploads % 10 == 0:
            logger.info(f"Progress: {successful_uploads} records uploaded")
        
    except Exception as e:
        logger.error(f"Error uploading record for {row['full_name']}: {str(e)}")
        failed_uploads += 1

logger.info(f"Import completed: {successful_uploads} records uploaded successfully, {failed_uploads} records failed")
# Out:
# 2025-05-29 13:29:20,283 - INFO - Read 3568 records from CSV
# 2025-05-29 13:29:22,542 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:22,549 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33295'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:23,406 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '33955'
#     'Date': 'Thu, 29 May 2025 05:29:22 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0165a9-0000-4d00-0000-6837f0b20000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:25,541 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:25,547 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '35362'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:25,816 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '36090'
#     'Date': 'Thu, 29 May 2025 05:29:25 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0166a9-0000-4d00-0000-6837f0b50000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:28,186 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:28,190 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34189'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:28,481 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34928'
#     'Date': 'Thu, 29 May 2025 05:29:27 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0168a9-0000-4d00-0000-6837f0b80000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:30,712 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:30,742 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34391'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:31,009 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '35123'
#     'Date': 'Thu, 29 May 2025 05:29:30 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0169a9-0000-4d00-0000-6837f0ba0000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:33,367 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:33,375 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34223'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:33,643 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34863'
#     'Date': 'Thu, 29 May 2025 05:29:32 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c016aa9-0000-4d00-0000-6837f0bd0000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:35,842 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:35,848 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34369'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:36,141 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '35108'
#     'Date': 'Thu, 29 May 2025 05:29:35 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c016ba9-0000-4d00-0000-6837f0bf0000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:38,113 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:38,117 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33922'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:38,386 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34697'
#     'Date': 'Thu, 29 May 2025 05:29:37 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c016da9-0000-4d00-0000-6837f0c20000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:40,369 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:40,378 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '36627'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:40,643 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '37328'
#     'Date': 'Thu, 29 May 2025 05:29:39 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c016fa9-0000-4d00-0000-6837f0c40000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:42,848 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:42,852 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34095'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:43,124 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34835'
#     'Date': 'Thu, 29 May 2025 05:29:42 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0170a9-0000-4d00-0000-6837f0c60000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:45,204 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:45,210 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34049'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:45,478 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34811'
#     'Date': 'Thu, 29 May 2025 05:29:44 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0172a9-0000-4d00-0000-6837f0c90000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:45,482 - INFO - Progress: 10 records uploaded
# 2025-05-29 13:29:47,904 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:47,942 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34865'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:48,214 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '35605'
#     'Date': 'Thu, 29 May 2025 05:29:47 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0173a9-0000-4d00-0000-6837f0cc0000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:50,214 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:50,217 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33749'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:50,484 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34514'
#     'Date': 'Thu, 29 May 2025 05:29:49 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0174a9-0000-4d00-0000-6837f0ce0000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:52,623 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:52,627 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34139'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:52,893 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34886'
#     'Date': 'Thu, 29 May 2025 05:29:52 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0176a9-0000-4d00-0000-6837f0d00000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:56,962 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:56,968 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '35870'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:57,235 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '36599'
#     'Date': 'Thu, 29 May 2025 05:29:56 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0179a9-0000-4d00-0000-6837f0d50000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:29:59,325 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:29:59,329 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34237'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:29:59,595 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34929'
#     'Date': 'Thu, 29 May 2025 05:29:58 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c017aa9-0000-4d00-0000-6837f0d70000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:30:01,601 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:30:01,605 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34096'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:30:01,872 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34839'
#     'Date': 'Thu, 29 May 2025 05:30:00 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c017ba9-0000-4d00-0000-6837f0d90000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:30:04,069 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:30:04,098 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33956'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:30:04,363 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34704'
#     'Date': 'Thu, 29 May 2025 05:30:03 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c017da9-0000-4d00-0000-6837f0dc0000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:30:06,279 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:30:06,282 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34405'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:30:06,551 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '35148'
#     'Date': 'Thu, 29 May 2025 05:30:05 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c017ea9-0000-4d00-0000-6837f0de0000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:30:08,437 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:30:08,442 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '35400'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:30:08,708 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '36103'
#     'Date': 'Thu, 29 May 2025 05:30:07 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c017fa9-0000-4d00-0000-6837f0e00000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:30:11,023 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:30:11,026 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33799'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:30:11,290 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34541'
#     'Date': 'Thu, 29 May 2025 05:30:10 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0180a9-0000-4d00-0000-6837f0e30000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:30:11,293 - INFO - Progress: 20 records uploaded
# 2025-05-29 13:30:13,331 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:30:13,336 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33989'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:30:13,604 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34736'
#     'Date': 'Thu, 29 May 2025 05:30:12 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0182a9-0000-4d00-0000-6837f0e50000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:30:15,687 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# ...
# A body is sent with the request
# 2025-05-29 13:43:12,582 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34405'
#     'Date': 'Thu, 29 May 2025 05:43:11 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0105ab-0000-4d00-0000-6837f3f00000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:43:15,056 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:43:15,063 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34110'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:43:15,334 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34827'
#     'Date': 'Thu, 29 May 2025 05:43:15 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0106ab-0000-4d00-0000-6837f3f30000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:43:18,141 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:43:18,147 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33765'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:43:18,417 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34501'
#     'Date': 'Thu, 29 May 2025 05:43:18 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0108ab-0000-4d00-0000-6837f3f60000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:43:20,665 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:43:20,671 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33865'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:43:20,941 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34607'
#     'Date': 'Thu, 29 May 2025 05:43:20 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c0109ab-0000-4d00-0000-6837f3f80000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:43:20,945 - INFO - Progress: 330 records uploaded
# 2025-05-29 13:43:23,239 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:43:23,252 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33909'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:43:23,527 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34675'
#     'Date': 'Thu, 29 May 2025 05:43:23 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c010aab-0000-4d00-0000-6837f3fb0000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:43:26,038 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:43:26,080 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '33859'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:43:26,352 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '34595'
#     'Date': 'Thu, 29 May 2025 05:43:26 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c010bab-0000-4d00-0000-6837f3fe0000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:43:28,868 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:43:28,873 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34405'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
# 2025-05-29 13:43:29,143 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '35157'
#     'Date': 'Thu, 29 May 2025 05:43:28 GMT'
#     'Content-Type': 'application/json'
#     'Server': 'Compute'
#     'x-ms-gatewayversion': 'REDACTED'
#     'x-ms-activity-id': 'REDACTED'
#     'x-ms-last-state-change-utc': 'REDACTED'
#     'etag': '"6c010cab-0000-4d00-0000-6837f4000000"'
#     'x-ms-resource-quota': 'REDACTED'
#     'x-ms-resource-usage': 'REDACTED'
#     'x-ms-schemaversion': 'REDACTED'
#     'lsn': 'REDACTED'
#     'x-ms-request-charge': 'REDACTED'
#     'x-ms-alt-content-path': 'REDACTED'
#     'x-ms-content-path': 'REDACTED'
#     'x-ms-quorum-acked-lsn': 'REDACTED'
#     'x-ms-current-write-quorum': 'REDACTED'
#     'x-ms-current-replica-set-size': 'REDACTED'
#     'x-ms-documentdb-partitionkeyrangeid': 'REDACTED'
#     'x-ms-xp-role': 'REDACTED'
#     'x-ms-global-Committed-lsn': 'REDACTED'
#     'x-ms-number-of-read-regions': 'REDACTED'
#     'x-ms-transport-request-id': 'REDACTED'
#     'x-ms-cosmos-llsn': 'REDACTED'
#     'x-ms-cosmos-quorum-acked-llsn': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-request-duration-ms': 'REDACTED'
#     'x-ms-serviceversion': 'REDACTED'
#     'x-ms-cosmos-physical-partition-id': 'REDACTED'
#     'x-ms-cosmos-internal-partition-id': 'REDACTED'
# 2025-05-29 13:43:31,378 - INFO - HTTP Request: POST https://linkedinsalesnav2.openai.azure.com/openai/deployments/text-embedding-ada-002/embeddings?api-version=2025-01-01-preview "HTTP/1.1 200 OK"
# 2025-05-29 13:43:31,387 - INFO - Request URL: 'https://linkedinsales-westus3.documents.azure.com:443/dbs/linkedin_data/colls/linkedin_data_vector/docs/'
# Request method: 'POST'
# Request headers:
#     'Cache-Control': 'no-cache'
#     'x-ms-version': 'REDACTED'
#     'x-ms-documentdb-query-iscontinuationexpected': 'REDACTED'
#     'x-ms-consistency-level': 'REDACTED'
#     'x-ms-session-token': 'REDACTED'
#     'x-ms-documentdb-partitionkey': 'REDACTED'
#     'x-ms-date': 'REDACTED'
#     'authorization': 'REDACTED'
#     'Content-Type': 'application/json'
#     'Accept': 'application/json'
#     'x-ms-cosmos-intended-collection-rid': 'REDACTED'
#     'Content-Length': '34134'
#     'User-Agent': 'azsdk-python-cosmos/4.9.0 Python/3.13.1 (Windows-11-10.0.26100-SP0)'
# A body is sent with the request
